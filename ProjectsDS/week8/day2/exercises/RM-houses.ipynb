# %% [markdown]
# ### Se pide:
#
# A partir del archivo "USA_Housing.csv", realizar la regresión lineal entre cada columna numérica con la columna 'price'.
#
# Cuando existe una columna(variable) que es la que se quiere comparar, se le llama 'target'.

# %% [markdown]
# La columna Price es "y"
# Se compara con todas las columnas
# target es 'y' fuera del rango del dataframe.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
housing = pd.read_csv('/Users/rochi/Desktop/TestFolder/DataScienceBootCampMIO/ProjectsDS/week8/day2/data/USA_Housing.csv')
housing
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
housing.shape
# Out:
# (5000, 7)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
housing.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
X = housing[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y = housing['Price']

# %%
X1 = housing['Avg. Area Income']

# %%
X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
X = np.array

# %%
X
# Out:
# <function numpy.array>

# %%
print(X)
# Out:
# <built-in function array>

# %%
X1 = X1.values.reshape(-1,1)
X1
# Out:
# array([[79545.45857432],
#        [79248.64245483],
#        [61287.06717866],
#        ...,
#        [63390.6868855 ],
#        [68001.33123509],
#        [65510.58180367]])

# %%
X2 = housing['Avg. Area House Age']

# %%
X2.shape
# Out:
# (5000, 1)

# %%
type(X2)
# Out:
# pandas.core.series.Series

# %%
X2 = X2.values.reshape(-1,1)
X2
# Out:
# array([[5.68286132],
#        [6.00289981],
#        [5.86588984],
#        ...,
#        [7.25059061],
#        [5.53438842],
#        [5.99230531]])

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
y.shape
# Out:
# (5000,)

# %%
y = y.values.reshape(-1,1)
y
# Out:
# array([[1059033.55787012],
#        [1505890.91484695],
#        [1058987.98787608],
#        ...,
#        [1030729.58315229],
#        [1198656.87240769],
#        [1298950.48026696]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=101)

lm = LinearRegression(n_jobs=-1)  # -1 to use all processor
    
lm.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
#REGRESION liNEAL DE CADA COLUMNA NUMERICA CON LA COLUMNA PRICE

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
plot_learning_curves(lin_reg, X1, y)
plt.show()

# %%
b = lin_reg.coef_ 
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-c78624d90450> in <module>
# ----> 1 b = lin_reg.coef_
#       2 b
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
print(lm.intercept_)
# Out:
# -215047.7718841161

# %%
a = lin_reg.intercept_
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-3d866ecb07f8> in <module>
# ----> 1 a = lin_reg.intercept_
#       2 a
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
def predict(model, number):
    to_predict = np.array([number]).reshape(1, -1)
    return model.predict(to_predict)

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions, edgecolor='black')

# %%
sns.distplot((y_test - predictions), bins = 50, hist_kws=dict(edgecolor="black", linewidth=1),color='Blue')

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 217619.5644321996
# MSE: 74402787880.48894
# RMSE: 272768.7443247282

# %%
X1
# Out:
# array([[79545.45857432],
#        [79248.64245483],
#        [61287.06717866],
#        ...,
#        [63390.6868855 ],
#        [68001.33123509],
#        [65510.58180367]])

# %%
y
# Out:
# array([[1059033.55787012],
#        [1505890.91484695],
#        [1058987.98787608],
#        ...,
#        [1030729.58315229],
#        [1198656.87240769],
#        [1298950.48026696]])

# %%
X2
# Out:
# array([[5.68286132],
#        [6.00289981],
#        [5.86588984],
#        ...,
#        [7.25059061],
#        [5.53438842],
#        [5.99230531]])

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
plot_learning_curves(lin_reg, X2, y)
lin_reg.fit(X2, y)

plt.scatter(X1, y, color='g')

# %%
new_model = LinearRegression()
plt.plot(X1, lin_reg.predict(X1), color='k')
new_model.fit(X1, y)

plt.scatter(X1, y, color='b')

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=101)

lm = LinearRegression(n_jobs=-1)  # -1 to use all processor
    
lm.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
plot_learning_curves(lin_reg, X2, y)
plt.show()

new_model = LinearRegression()
new_model.fit(X2, y)

plt.scatter(X2, y, color='b')

# %%
new_home = np.array([[100000.0, 20.0, 8.0, 9.0, 10000.0]])
new_home
# Out:
# array([[1.e+05, 2.e+01, 8.e+00, 9.e+00, 1.e+04]])

# %%
new_model = LinearRegression()
plt.plot(X1, lin_reg.predict(X1), color='k')
new_model.fit(X1, y)
# Out:
# LinearRegression()

# %%
lm.score(X_train, y_train) * 100
# Out:
# 40.63479319730665

# %%
lm.score(X_test, y_test) * 100
# Out:
# 41.93148429872476
